# %%
import cv2
from matplotlib import pyplot as plt

# Load the image
image_path = '/Users/nisargp/PycharmProjects/CV/Assignment /VinBigDatasetSmall/Train_HistEq/0d5597f8b17330d498fc5e13893e3081.jpg'  # Update this path to your image's path
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read the image in grayscale

# Apply global thresholding
ret, thresh_global = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# Display the original and thresholded image
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(thresh_global, cmap='gray')
plt.title('Global Thresholding')
plt.axis('off')

plt.show()

# %%
import cv2
import os
from matplotlib import pyplot as plt

# Define directories
input_dir = '/Users/nisargp/PycharmProjects/CV/Assignment /VinBigDatasetSmall/Train_HistEq'
output_dir = '/Users/nisargp/PycharmProjects/CV/Assignment /VinBigDatasetSmall/Train_GlobalThreshold'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Function to apply global thresholding
def apply_global_thresholding(input_directory, output_directory):
    for filename in os.listdir(input_directory):
        if filename.endswith(".jpg"):  # Check if the file is an image
            # Read the image in grayscale
            img_path = os.path.join(input_directory, filename)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

            # Apply global thresholding
            _, thresh = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

            # Save the thresholded image
            output_path = os.path.join(output_directory, filename)
            cv2.imwrite(output_path, thresh)

            # For demonstration, show the comparison for the first image only
            if filename == os.listdir(input_directory)[0]:
                plt.figure(figsize=(10, 5))
                plt.subplot(1, 2, 1)
                plt.imshow(img, cmap='gray')
                plt.title('Original Image')
                plt.axis('off')

                plt.subplot(1, 2, 2)
                plt.imshow(thresh, cmap='gray')
                plt.title('Global Thresholding')
                plt.axis('off')

                plt.show()
            
            # Break after the first image for demo
            break

# Apply the function
apply_global_thresholding(input_dir, output_dir)

# %%
import cv2
import os
from matplotlib import pyplot as plt

# Define directories
input_dir = '/Users/nisargp/PycharmProjects/CV/Assignment /VinBigDatasetSmall/Train_HistEq'
output_dir = '/Users/nisargp/PycharmProjects/CV/Assignment /VinBigDatasetSmall/Train_GlobalThreshold'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Function to apply global thresholding
def apply_global_thresholding(input_directory, output_directory):
    first_image = True  # Indicator for the first image
    for filename in os.listdir(input_directory):
        if filename.endswith(".jpg"):  # Check if the file is an image
            # Read the image in grayscale
            img_path = os.path.join(input_directory, filename)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

            # Apply global thresholding
            _, thresh = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

            # Save the thresholded image
            output_path = os.path.join(output_directory, filename)
            cv2.imwrite(output_path, thresh)

            # For demonstration, show the comparison for the first image only
            if first_image:
                plt.figure(figsize=(10, 5))
                plt.subplot(1, 2, 1)
                plt.imshow(img, cmap='gray')
                plt.title('Original Image')
                plt.axis('off')

                plt.subplot(1, 2, 2)
                plt.imshow(thresh, cmap='gray')
                plt.title('Global Thresholding')
                plt.axis('off')

                plt.show()
                first_image = False  # Change the flag after the first image is processed

# Apply the function
apply_global_thresholding(input_dir, output_dir)

# %%
import cv2
import os
from matplotlib import pyplot as plt

# Define directories
input_dir = '/Users/nisargp/PycharmProjects/CV/Assignment /VinBigDatasetSmall/Train_HistEq'
output_dir = '/Users/nisargp/PycharmProjects/CV/Assignment /VinBigDatasetSmall/Train_OtsuThreshold'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Function to apply Otsu's thresholding
def apply_otsu_thresholding(input_directory, output_directory):
    first_image = True  # Indicator for the first image
    for filename in os.listdir(input_directory):
        if filename.endswith(".jpg"):  # Check if the file is an image
            # Read the image in grayscale
            img_path = os.path.join(input_directory, filename)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

            # Apply Otsu's thresholding
            _, thresh = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

            # Save the thresholded image
            output_path = os.path.join(output_directory, filename)
            cv2.imwrite(output_path, thresh)

            # For demonstration, show the comparison for the first image only
            if first_image:
                plt.figure(figsize=(10, 5))
                plt.subplot(1, 2, 1)
                plt.imshow(img, cmap='gray')
                plt.title('Original Image')
                plt.axis('off')

                plt.subplot(1, 2, 2)
                plt.imshow(thresh, cmap='gray')
                plt.title("Otsu's Thresholding")
                plt.axis('off')

                plt.show()
                first_image = False  # Change the flag after the first image is processed

# Apply the function
apply_otsu_thresholding(input_dir, output_dir)

# %%
import cv2
import os
from matplotlib import pyplot as plt

# Define directories
input_dir = '/Users/nisargp/PycharmProjects/CV/Assignment /VinBigDatasetSmall/Train_Denoised'
output_dir = '/Users/nisargp/PycharmProjects/CV/Assignment /VinBigDatasetSmall/Train_AdaptiveThreshold'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Function to apply adaptive thresholding
def apply_adaptive_thresholding(input_directory, output_directory):
    first_image = True  # Indicator for the first image
    for filename in os.listdir(input_directory):
        if filename.endswith(".jpg"):  # Check if the file is an image
            # Read the image in grayscale
            img_path = os.path.join(input_directory, filename)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

            # Apply adaptive thresholding
            thresh = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, 
                                           cv2.THRESH_BINARY, 11, 2)

            # Save the thresholded image
            output_path = os.path.join(output_directory, filename)
            cv2.imwrite(output_path, thresh)

            # For demonstration, show the comparison for the first image only
            if first_image:
                plt.figure(figsize=(10, 5))
                plt.subplot(1, 2, 1)
                plt.imshow(img, cmap='gray')
                plt.title('Original Image')
                plt.axis('off')

                plt.subplot(1, 2, 2)
                plt.imshow(thresh, cmap='gray')
                plt.title('Adaptive Thresholding')
                plt.axis('off')

                plt.show()
                first_image = False  # Change the flag after the first image is processed

# Apply the function
apply_adaptive_thresholding(input_dir, output_dir)

# %%
import cv2
import os
from matplotlib import pyplot as plt

# Define directories
input_dir = '/Users/nisargp/PycharmProjects/CV/Assignment /VinBigDatasetSmall/Train_Denoised'
output_dir = '/Users/nisargp/PycharmProjects/CV/Assignment /VinBigDatasetSmall/Train_GaussianThreshold'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Function to apply Gaussian thresholding
def apply_gaussian_thresholding(input_directory, output_directory):
    first_image = True  # Indicator for the first image
    for filename in os.listdir(input_directory):
        if filename.endswith(".jpg"):  # Check if the file is an image
            # Read the image in grayscale
            img_path = os.path.join(input_directory, filename)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

            # Apply Gaussian adaptive thresholding
            thresh = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                           cv2.THRESH_BINARY, 11, 2)

            # Save the thresholded image
            output_path = os.path.join(output_directory, filename)
            cv2.imwrite(output_path, thresh)

            # For demonstration, show the comparison for the first image only
            if first_image:
                plt.figure(figsize=(10, 5))
                plt.subplot(1, 2, 1)
                plt.imshow(img, cmap='gray')
                plt.title('Original Image')
                plt.axis('off')

                plt.subplot(1, 2, 2)
                plt.imshow(thresh, cmap='gray')
                plt.title('Gaussian Thresholding')
                plt.axis('off')

                plt.show()
                first_image = False  # Change the flag after the first image is processed

# Apply the function
apply_gaussian_thresholding(input_dir, output_dir)

# %%
import cv2
import os
from matplotlib import pyplot as plt

# Define directory and file names
base_dir = '/Users/nisargp/PycharmProjects/CV/Assignment /VinBigDatasetSmall'
image_filename = '0bef06d948ac1fe20ade505ba9960885.jpg'  
# Define paths for the original and thresholded images
original_img_path = os.path.join(base_dir, 'Train_Denoised', image_filename)
global_thresh_path = os.path.join(base_dir, 'Train_GlobalThreshold', image_filename)
otsu_thresh_path = os.path.join(base_dir, 'Train_OtsuThreshold', image_filename)
adaptive_thresh_path = os.path.join(base_dir, 'Train_AdaptiveThreshold', image_filename)
gaussian_thresh_path = os.path.join(base_dir, 'Train_GaussianThreshold', image_filename)

# Read all images
original_img = cv2.imread(original_img_path, cv2.IMREAD_GRAYSCALE)
global_thresh_img = cv2.imread(global_thresh_path, cv2.IMREAD_GRAYSCALE)
otsu_thresh_img = cv2.imread(otsu_thresh_path, cv2.IMREAD_GRAYSCALE)
adaptive_thresh_img = cv2.imread(adaptive_thresh_path, cv2.IMREAD_GRAYSCALE)
gaussian_thresh_img = cv2.imread(gaussian_thresh_path, cv2.IMREAD_GRAYSCALE)

# Create a subplot of 1 row and 5 columns
plt.figure(figsize=(20, 10))  # Adjust the figure size as needed

# Original image
plt.subplot(1, 5, 1)
plt.imshow(original_img, cmap='gray')
plt.title('Original Image')
plt.axis('off')

# Global Thresholding image
plt.subplot(1, 5, 2)
plt.imshow(global_thresh_img, cmap='gray')
plt.title('Global Thresholding')
plt.axis('off')

# Otsu's Thresholding image
plt.subplot(1, 5, 3)
plt.imshow(otsu_thresh_img, cmap='gray')
plt.title("Otsu's Thresholding")
plt.axis('off')

# Adaptive Thresholding image
plt.subplot(1, 5, 4)
plt.imshow(adaptive_thresh_img, cmap='gray')
plt.title('Adaptive Thresholding')
plt.axis('off')

# Gaussian Thresholding image
plt.subplot(1, 5, 5)
plt.imshow(gaussian_thresh_img, cmap='gray')
plt.title('Gaussian Thresholding')
plt.axis('off')

# Display the plot
plt.show()
